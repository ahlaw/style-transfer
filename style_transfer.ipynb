# %%
# !git clone https://github.com/ahlaw/style-transfer

# %%
# !wget -qO content.jpg "https://storage.googleapis.com/download.tensorflow.org/example_images/YellowLabradorLooking_new.jpg"
# !wget -qO style.jpg "https://storage.googleapis.com/download.tensorflow.org/example_images/Vassily_Kandinsky%2C_1913_-_Composition_7.jpg"
# !ls

# %%
from IPython.display import Image, display
print('Content Image')
display(Image('content.jpg', width=512))
print('Style Image')
display(Image('style.jpg', width=512))
# Out:
# Content Image
# Style Image

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass
# Out:
# TensorFlow 2.x selected.

# %%
# !python style-transfer/main.py --content content.jpg --style style.jpg --output output.jpg

# %%
print('Generated Image')
display(Image('output.jpg'))
# Out:
# Generated Image

# %%
try:
  from google.colab import files
except ImportError:
   pass
else:
  files.download('content.jpg')
  files.download('style.jpg')
  files.download('output.jpg')
